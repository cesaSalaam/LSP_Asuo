# %% [markdown]
# <a href="https://colab.research.google.com/github/cesaSalaam/LSP_Asuo/blob/main/Hello_Black_World_Specialized_Visualizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Hello, Black World! 🌍**
# ## **Let's learn about Specialized Visualizations in Python**
#
# ---

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from statsmodels.graphics.mosaicplot import mosaic

# %% [markdown]
# # **Heat Maps**

# %%
# Some sector and geographies for illustration
sector=["Technology","Consumer Discretionary", "Real Estate", "Financial Services"]

geography=["Ghana", "Nigeria", "South Africa", "Haiti"]



# Simulate market returns based on a random 
returns= np.array([[40,13,20,37],
         [30,41,37,46],
         [89,50,65,55],
         [35,20,25,35]])

fig, ax = plt.subplots()
im = ax.imshow(returns)

# We want to show all ticks...
ax.set_xticks(np.arange(len(sector)))
ax.set_yticks(np.arange(len(geography)))

# ... and label them with the respective list entries
ax.set_xticklabels(sector)
ax.set_yticklabels(geography)


ax.set_title("Country revenue by sector in billions")
fig.tight_layout()
plt.show()

# %% [markdown]
# # **Correlograms**
#
# We usually use a correlogram to display correlation data over a time period.

# %%
# data Import 
# Fixing random state for reproducibility
np.random.seed(2434548631)
x, y = np.random.randn(2, 100)

fig, ax1  = plt.subplots()

ax1.xcorr(x, y, usevlines=True, maxlags=50, normed=True, lw=2)

plt.show()

# %% [markdown]
# # **Mosaic**

# %%
myDataframe = pd.DataFrame({'Country' : ['Ghana', 'Haiti', 'Egypt', 'Ghana', 'Jamiaca', 'Ghana'], 'Gender' : ['Male', 'Female', 'Male', 'Female', 'Female', 'Female']})
myDataframe.head()
# Out:
#    Country  Gender
# 0    Ghana    Male
# 1    Haiti  Female
# 2    Egypt    Male
# 3    Ghana  Female
# 4  Jamiaca  Female

# %%
mosaic(myDataframe, ['Country', 'Gender'])
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  {('Ghana', 'Male'): (0.0, 0.0, 0.4926108374384236, 0.3322259136212624),
#   ('Ghana', 'Female'): (0.0,
#    0.33554817275747506,
#    0.4926108374384236,
#    0.6644518272425249),
#   ('Haiti', 'Male'): (0.49753694581280783, 0.0, 0.1642036124794745, 0.0),
#   ('Haiti', 'Female'): (0.49753694581280783,
#    0.0033222591362126247,
#    0.1642036124794745,
#    0.9966777408637874),
#   ('Egypt', 'Male'): (0.6666666666666665,
#    0.0,
#    0.1642036124794746,
#    0.9966777408637874),
#   ('Egypt', 'Female'): (0.6666666666666665, 1.0, 0.1642036124794746, 0.0),
#   ('Jamiaca', 'Male'): (0.8357963875205254, 0.0, 0.1642036124794745, 0.0),
#   ('Jamiaca', 'Female'): (0.8357963875205254,
#    0.0033222591362126247,
#    0.1642036124794745,
#    0.9966777408637874)})
